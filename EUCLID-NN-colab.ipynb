# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorLob/EUCLID-hyperelasticity-NN/blob/main/EUCLID-NN-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HectorLob/EUCLID-hyperelasticity-NN.git

# %%
# %cd EUCLID-hyperelasticity-NN

# %% [markdown]
# ## Material model options:
# - 'NeoHookean'
# - 'Anisotropy45'
# - 'Anisotropy60'
# - 'Isihara'
# - 'HainesWilson'
# - 'GentThomas'
# - 'ArrudaBoyce'
# - 'Ogden'
# - 'Holzapfel'

# %%
MATERIAL_MODEL = 'Isihara'
NOISE_LEVEL = 'high' # or 'high'

# %%
from google.colab import drive
drive.mount('/content/drive') # mount google drive to save the results

# %%
# %cd drivers
# !python3 main.py $MATERIAL_MODEL $NOISE_LEVEL
# Out:
# /home/hector/Github/EUCLID/EUCLID-hyperelasticity-NN/drivers
#
# -----------------------------------------------------
# Setting device to:  -1
# Test:  cpu
# -----------------------------------------------------
#
#
# -----------------------------------------------------
# Setting device to:  -1
# Test:  cpu
# -----------------------------------------------------
#
# Loading data for loadstep 10...
#
# -----------------------------------------------------
# Loading data:  ../fem-data/noise=high/Isihara/10/
# Applying noise to displacements: 0.0
# -----------------------------------------------------
#
# Loading data for loadstep 20...
#
# -----------------------------------------------------
# Loading data:  ../fem-data/noise=high/Isihara/20/
# Applying noise to displacements: 0.0
# -----------------------------------------------------
#
# Loading data for loadstep 30...
#
# -----------------------------------------------------
# Loading data:  ../fem-data/noise=high/Isihara/30/
# ...
